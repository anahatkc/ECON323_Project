# %% [markdown]
# ### ECON 323 FINAL PROJECT

# %%
import pandas as pd

# %%
# reading in new data 

results15 = pd.read_csv("DATA/2015Results.csv")
results19 = pd.read_csv("DATA/2019Results.csv")
results19.head()
# Out:
#               Name                         Party  Election  Politician ID  \
# 0     Dean Allison  Conservative Party of Canada        43              5
# 1    Charlie Angus          New Democratic Party        43             11
# 2    Larry Bagnell       Liberal Party of Canada        43             15
# 3    Navdeep Bains       Liberal Party of Canada        43             16
# 4  Carolyn Bennett       Liberal Party of Canada        43             24
#
#    Riding ID Province Gender ranfor44 reelected44  QuestionPeriod  \
# 0      35068       ON      M      Yes         Yes               1
# 1      35107       ON      M      Yes         Yes              41
# 2      60001       YT      M       No           .               0
# 3      35062       ON      M       No           .              32
# 4      35090       ON      F      Yes         Yes              38
#
#    PvtMemBills  StatementsByMembers Backbencher          DOB  \
# 0            0                    2          Yes  1965-02-18
# 1            0                    3          Yes  1962-11-14
# 2            0                    0          Yes  1949-12-19
# 3            0                    0           No  1977-06-16
# 4            0                    0           No  1950-12-20
#
#    AgeOnElectionDay  YearsServedAtElection
# 0              56.0              17.241096
# 1              58.0              17.241096
# 2              71.0              16.356164
# 3              44.0              12.769863
# 4              70.0              24.317808

# %%
# renaming columns
Results15 = results15.rename(columns = {"RidingID":"Riding ID", "ranfor43":"RanForNE", "reelected43":"Reelected", "DOB1":"DOB", "YearsServedAtTimeOfElection":"YearsInHOC"})
Results19 = results19.rename(columns = {"Election":"Parliament", "ranfor44":"RanForNE", "reelected44":"Reelected", "StatementsByMembers":"Statements", "YearsServedAtElection":"YearsInHOC"})

# %%
# merging dataframes
Results_Full = pd.concat([Results15, Results19])
Results_Full.reset_index()
# combining 2015 and 2019 datasets leds to MPs showing up twice -- doesn't matter for analysis because each row is just one observation - person itself doesnt matter
# Out:
#      index            Name                         Party  Parliament  \
# 0        0    Dean Allison  Conservative Party of Canada          42
# 1        1    Rona Ambrose  Conservative Party of Canada          42
# 2        2  David Anderson  Conservative Party of Canada          42
# 3        3   Charlie Angus          New Democratic Party          42
# 4        4   Larry Bagnell       Liberal Party of Canada          42
# ..     ...             ...                           ...         ...
# 691    335  Maninder Sidhu       Liberal Party of Canada          43
# 692    336      Nelly Shin  Conservative Party of Canada          43
# 693    337    Rob Morrison  Conservative Party of Canada          43
# 694    338       Marci Ien       Liberal Party of Canada          43
# 695    339     Ya'ara Saks       Liberal Party of Canada          43
#
#      Politician ID  Riding ID Province Gender RanForNE Reelected  \
# 0                5      35068       ON      M      Yes       Yes
# 1                6      48033       AB      F       No         .
# 2                9      47002       SK      M       No         .
# 3               11      35107       ON      M      Yes       Yes
# 4               15      60001       YT      M      Yes       Yes
# ..             ...        ...      ...    ...      ...       ...
# 691          12210      35009       ON      M      Yes       Yes
# 692          12222      59023       BC      F      Yes        No
# 693          12228      59015       BC      M      Yes       Yes
# 694          12231      35108       ON      F      Yes       Yes
# 695          12234      35118       ON      F      Yes       Yes
#
#      QuestionPeriod  PvtMemBills  Statements Backbencher          DOB  \
# 0                42            0          19           No  1965-02-18
# 1               457            1           3           No  1969-03-15
# 2                53            1          20           No  1957-08-15
# 3               168            0          15          Yes  1962-11-14
# 4                11            1          15          Yes  1949-12-19
# ..              ...          ...         ...          ...         ...
# 691               5            0           3          Yes  1984-04-26
# 692              13            0           6           No  1971-01-01
# 693              10            0           4           No  1956-05-03
# 694               4            0           2          Yes  1969-07-29
# 695               8            0           2          Yes  1973-03-09
#
#      AgeOnElectionDay  YearsInHOC
# 0                54.0   15.323288
# 1                50.0   15.323288
# 2                62.0   18.909589
# 3                56.0   15.323288
# 4                69.0   16.350685
# ..                ...         ...
# 691              37.0    1.917808
# 692              50.0    1.917808
# 693              65.0    1.917808
# 694              52.0    0.901370
# 695              48.0    0.901370
#
# [696 rows x 17 columns]

# %%
Results_Dummy = pd.DataFrame(data=Results_Full, columns=['Gender', 'RanForNE', 'Reelected', 'Party'])
Results_Dummy

#just_dummies = pd.get_dummies(Results_Dummy)
#just_dummies

#Dummies = just_dummies.drop(columns=['Gender_M', 'RanForNE_No', 'Reelected_.', 'Reelected_No', 'Party_Bloc Québécois', 'Party_Green Party of Canada', 'Party_Independent'])
#Dummies

#Results1 = pd.concat([Results_Full, Dummies], axis = 1)
#Results1

#Results = Results1.drop(columns=['Gender', 'RanForNE', 'Reelected', 'Party', 'DOB'])
#Results

Results_Dummy1 = pd.DataFrame(data=Results_Full, columns=['Backbencher', 'Parliament'])
Results_Dummy1
# Out:
#      Backbencher  Parliament
# 0            NaN          42
# 1            NaN          42
# 2            NaN          42
# 3            NaN          42
# 4            NaN          42
# ..           ...         ...
# 335          NaN          43
# 336          NaN          43
# 337          NaN          43
# 338          NaN          43
# 339          NaN          43
#
# [696 rows x 2 columns]
